# %%
import json

# Load the matched data
with open('matched_data.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Count items
num_items = len(data)

print(f"Total items in matched_data.json: {num_items}")
print(f"\nSample item:")
print(json.dumps(data[0], indent=2))
# Out:
# Total items in matched_data.json: 136
#
# Sample item:
# {
#   "product_id": "8468",
#   "image": "8468.jpg",
#   "display_name": "Scullers For Her Women Layered Black Tunics",
#   "category": "Tunics",
#   "sub_category": "Kurta",
#   "brand": "Scullers For Her",
#   "gender": "Women",
#   "color": "Black",
#   "primary_material": "Viscose",
#   "material_composition": "100% viscose",
#   "sleeve_type": "Three-fourth sleeve",
#   "neck_type": "V-neck",
#   "fit_type": "Regular",
#   "occasion": [
#     "Casual",
#     "Semi-formal",
#     "Party"
#   ],
#   "style_features": [
#     "Sequins on chest",
#     "Buttoned flap on elbow",
#     "Vented hem"
#   ],
#   "care_instructions": "Dry clean only, Do not bleach, Steam iron",
#   "styling_suggestions": "Team with leggings and heels",
#   "skin_tone_compatibility": [
#     "Fair",
#     "Medium",
#     "Olive",
#     "Dark"
#   ],
#   "season": [
#     "All seasons"
#   ],
#   "price": 1899,
# ...
